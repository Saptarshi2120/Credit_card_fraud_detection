# %%
# Importing the necessary classes
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
# Loading the data from csv file to a Pandas DataFrame
data = pd.read_csv("CreditCardFraud.csv")
data
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
#       PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         0  ...      20940      19146      19131      2000     36681
# 1         0  ...      19394      19619      20024      2500      1815
# 2         0  ...     542653     483003     473944     55000     40000
# 3         0  ...        221       -159        567       380       601
# 4         0  ...      12211      11793       3719      3329         0
# ...     ...  ...        ...        ...        ...       ...       ...
# 996      -1  ...      -2618      95748     101299      3320      5000
# 997       0  ...      97041     103541       3632      5000      2000
# 998      -1  ...        657       1332        780         0      2806
# 999      -2  ...          0          0          0         0         0
# 1000     -2  ...       2527          0          0      9664      3420
#
#       PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0        10000      9000       689       679                           0
# 1          657      1000      1000       800                           0
# 2        38000     20239     13750     13770                           0
# 3            0       581      1687      1542                           0
# 4          432      1000      1000      1000                           0
# ...        ...       ...       ...       ...                         ...
# 996          0    100000      7186         0                           0
# 997      89000      6500        91      1504                           0
# 998       2256      2274       780         0                           0
# 999          0         0         0         0                           1
# 1000      2612         0         0         0                           1
#
# [1001 rows x 24 columns]

# %%
# Printing the first 20 rows of the dataframe
data.head(20)
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0       50000    1          2         1   57     -1      0     -1      0
# 1       50000    1          1         2   37      0      0      0      0
# 2      500000    1          1         2   29      0      0      0      0
# 3      100000    2          2         2   23      0     -1     -1      0
# 4      140000    2          3         1   28      0      0      2      0
# 5       20000    1          3         2   35     -2     -2     -2     -2
# 6      200000    2          3         2   34      0      0      2      0
# 7      260000    2          1         2   51     -1     -1     -1     -1
# 8      630000    2          2         2   41     -1      0     -1     -1
# 9       70000    1          2         2   30      1      2      2      0
# 10     250000    1          1         2   29      0      0      0      0
# 11      50000    2          3         3   23      1      2      0      0
# 12      20000    1          1         2   24      0      0      2      2
# 13     320000    1          1         1   49      0      0      0     -1
# 14     360000    2          1         1   49      1     -2     -2     -2
# 15     180000    2          1         2   29      1     -2     -2     -2
# 16     130000    2          3         2   39      0      0      0      0
# 17     120000    2          2         1   39     -1     -1     -1     -1
# 18      70000    2          2         2   26      2      0      0      2
# 19     450000    2          1         1   40     -2     -2     -2     -2
#
#     PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0       0  ...      20940      19146      19131      2000     36681     10000
# 1       0  ...      19394      19619      20024      2500      1815       657
# 2       0  ...     542653     483003     473944     55000     40000     38000
# 3       0  ...        221       -159        567       380       601         0
# 4       0  ...      12211      11793       3719      3329         0       432
# 5      -1  ...          0      13007      13912         0         0         0
# 6       0  ...       2513       1828       3731      2306        12        50
# 7      -1  ...       8517      22287      13668     21818      9966      8583
# 8      -1  ...       6500       6500       2870      1000      6500      6500
# 9       0  ...      66782      36137      36894      3200         0      3000
# 10      0  ...      59696      56875      55512      3000      3000      3000
# 11      0  ...      28771      29531      30211         0      1500      1100
# 12      2  ...      18338      17905      19104      3200         0      1500
# 13     -1  ...      70074       5856     195599     10358     10000     75940
# 14     -2  ...          0          0          0         0         0         0
# 15     -2  ...          0          0          0         0         0         0
# 16      0  ...      20616      11802        930      3000      1537      1000
# 17     -1  ...          0        632        316       316       316         0
# 18      2  ...      44006      46905      46012      2007      3582         0
# 19     -2  ...        560          0          0     19428      1473       560
#
#     PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0       9000       689       679                           0
# 1       1000      1000       800                           0
# 2      20239     13750     13770                           0
# 3        581      1687      1542                           0
# 4       1000      1000      1000                           0
# 5      13007      1122         0                           0
# 6        300      3738        66                           0
# 7      22301         0      3640                           0
# 8       6500      2870         0                           0
# 9       3000      1500         0                           1
# 10      3000      3000      3000                           0
# 11      1200      1300      1100                           0
# 12         0      1650         0                           1
# 13     20000    195599     50000                           0
# 14         0         0         0                           0
# 15         0         0         0                           0
# 16      2000       930     33764                           0
# 17       632       316         0                           1
# 18      3601         0      1820                           1
# 19         0         0      1128                           1
#
# [20 rows x 24 columns]

# %%
# Number of rows and columns in the dataframe
data.shape
# Out:
# (1001, 24)

# %%
# Name of all columns in the dataframe
data.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
# Getting more information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   1001 non-null   int64
#  1   SEX                         1001 non-null   int64
#  2   EDUCATION                   1001 non-null   int64
#  3   MARRIAGE                    1001 non-null   int64
#  4   AGE                         1001 non-null   int64
#  5   PAY_0                       1001 non-null   int64
#  6   PAY_2                       1001 non-null   int64
#  7   PAY_3                       1001 non-null   int64
#  8   PAY_4                       1001 non-null   int64
#  9   PAY_5                       1001 non-null   int64
#  10  PAY_6                       1001 non-null   int64
#  11  BILL_AMT1                   1001 non-null   int64
#  12  BILL_AMT2                   1001 non-null   int64
#  13  BILL_AMT3                   1001 non-null   int64
#  14  BILL_AMT4                   1001 non-null   int64
#  15  BILL_AMT5                   1001 non-null   int64
#  16  BILL_AMT6                   1001 non-null   int64
#  17  PAY_AMT1                    1001 non-null   int64
#  18  PAY_AMT2                    1001 non-null   int64
#  19  PAY_AMT3                    1001 non-null   int64
#  20  PAY_AMT4                    1001 non-null   int64
#  21  PAY_AMT5                    1001 non-null   int64
#  22  PAY_AMT6                    1001 non-null   int64
#  23  default payment next month  1001 non-null   int64
# dtypes: int64(24)
# memory usage: 187.8 KB

# %%
# checking for missing values in each column
data.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# Getting some statistical measures about the data
data.describe()
# Out:
#            LIMIT_BAL          SEX    EDUCATION     MARRIAGE          AGE  \
# count    1001.000000  1001.000000  1001.000000  1001.000000  1001.000000
# mean   167532.467532     1.589411     1.776224     1.604396    34.945055
# std    130587.921320     0.492187     0.750916     0.532298     9.219760
# min     10000.000000     1.000000     1.000000     0.000000    21.000000
# 25%     50000.000000     1.000000     1.000000     1.000000    28.000000
# 50%    140000.000000     2.000000     2.000000     2.000000    33.000000
# 75%    240000.000000     2.000000     2.000000     2.000000    41.000000
# max    700000.000000     2.000000     6.000000     3.000000    75.000000
#
#              PAY_0        PAY_2        PAY_3        PAY_4        PAY_5  ...  \
# count  1001.000000  1001.000000  1001.000000  1001.000000  1001.000000  ...
# mean     -0.004995    -0.161838    -0.164835    -0.283716    -0.283716  ...
# std       1.173446     1.228732     1.262459     1.184662     1.170224  ...
# min      -2.000000    -2.000000    -2.000000    -2.000000    -2.000000  ...
# 25%      -1.000000    -1.000000    -1.000000    -1.000000    -1.000000  ...
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# max       8.000000     7.000000     7.000000     7.000000     7.000000  ...
#
#            BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count    1001.000000    1001.000000    1001.000000    1001.000000
# mean    40748.408591   39078.666334   38012.011988    5382.339660
# std     68206.929510   63108.238729   63074.415024   12180.755275
# min     -3684.000000  -28335.000000 -339603.000000       0.000000
# 25%      1423.000000    1206.000000     830.000000    1000.000000
# 50%     17710.000000   17580.000000   15846.000000    2184.000000
# 75%     48851.000000   46404.000000   46557.000000    5090.000000
# max    628699.000000  484612.000000  473944.000000  199646.000000
#
#             PAY_AMT2       PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count    1001.000000    1001.000000    1001.000000    1001.000000
# mean     5051.400599    4176.149850    4671.488511    5331.049950
# std     15626.153184   10514.647502   13269.943983   16812.536877
# min         0.000000       0.000000       0.000000       0.000000
# 25%       390.000000     228.000000     148.000000     189.000000
# 50%      1710.000000    1206.000000    1398.000000    1306.000000
# 75%      4500.000000    3720.000000    4000.000000    3745.000000
# max    285138.000000  133657.000000  188840.000000  195599.000000
#
#             PAY_AMT6  default payment next month
# count    1001.000000                 1001.000000
# mean     5090.704296                    0.213786
# std     23658.888052                    0.410183
# min         0.000000                    0.000000
# 25%         0.000000                    0.000000
# 50%      1250.000000                    0.000000
# 75%      3784.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 24 columns]

# %%
# Grouping the data based on the target variable
data.groupby('default payment next month').mean()
# Out:
#                                 LIMIT_BAL       SEX  EDUCATION  MARRIAGE  \
# default payment next month
# 0                           170127.064803  1.602287   1.763659  1.608640
# 1                           157990.654206  1.542056   1.822430  1.588785
#
#                                   AGE     PAY_0     PAY_2     PAY_3     PAY_4  \
# default payment next month
# 0                           34.687421 -0.174079 -0.265565 -0.287166 -0.383736
# 1                           35.892523  0.616822  0.219626  0.285047  0.084112
#
#                                PAY_5  ...     BILL_AMT3     BILL_AMT4  \
# default payment next month            ...
# 0                          -0.382465  ...  44411.481576  40364.139771
# 1                           0.079439  ...  46816.691589  42161.584112
#
#                                BILL_AMT5     BILL_AMT6     PAY_AMT1  \
# default payment next month
# 0                           38420.895807  37769.662008  5939.581957
# 1                           41497.663551  38903.271028  3333.042056
#
#                                PAY_AMT2     PAY_AMT3     PAY_AMT4  \
# default payment next month
# 0                           5607.763659  4526.462516  5086.377382
# 1                           3005.336449  2887.850467  3145.705607
#
#                                PAY_AMT5     PAY_AMT6
# default payment next month
# 0                           5741.191868  5140.388818
# 1                           3822.724299  4907.985981
#
# [2 rows x 23 columns]

# %%
# distribution of target Variable
data['default payment next month'].value_counts()
# Out:
# 0    787
# 1    214
# Name: default payment next month, dtype: int64

# %%
pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in c:\users\sapta\anaconda3\lib\site-packages (3.6.6)
# Requirement already satisfied: ydata-profiling in c:\users\sapta\anaconda3\lib\site-packages (from pandas-profiling) (4.3.1)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (4.3.1)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.21.5)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (4.64.1)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.1.12)
# Requirement already satisfied: typeguard<3,>=2.13.2 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (2.13.3)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (2.28.1)
# Requirement already satisfied: pydantic<2,>=1.8.1 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.10.9)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.7.5)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.2)
# Requirement already satisfied: scipy<1.11,>=1.4.1 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Requirement already satisfied: matplotlib<4,>=3.2 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (3.5.2)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.12.3)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (2.11.3)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.13.2)
# Requirement already satisfied: pandas!=1.4.0,<2.1,>1.1 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.4.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (6.0)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Requirement already satisfied: dacite>=1.8 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.8.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\sapta\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.11.2)
# Requirement already satisfied: pillow in c:\users\sapta\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (9.2.0)
# Requirement already satisfied: PyWavelets in c:\users\sapta\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.3.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\sapta\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (21.4.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\sapta\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (0.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\sapta\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (2.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sapta\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sapta\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sapta\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sapta\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sapta\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\sapta\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sapta\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sapta\anaconda3\lib\site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling->pandas-profiling) (2022.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\sapta\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\sapta\anaconda3\lib\site-packages (from pydantic<2,>=1.8.1->ydata-profiling->pandas-profiling) (4.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sapta\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sapta\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\sapta\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sapta\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\sapta\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.2)
# Requirement already satisfied: colorama in c:\users\sapta\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->pandas-profiling) (0.4.5)
# Requirement already satisfied: six in c:\users\sapta\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_profiling import ProfileReport
# Out:
# C:\Users\sapta\AppData\Local\Temp\ipykernel_11612\2274191625.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
# Exploratory Data Analysis using Pandas Profiling 
profile = ProfileReport(data, title = "Pandas Profile Report")

# %%
# Summarizing the data based on the target variable
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
profile.to_file(output_file='Credit_Card.html')
# Out:
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
x = data.drop(labels = ['default payment next month'],axis = 1)
x
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
#       PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0         0  ...      35835      20940      19146      19131      2000
# 1         0  ...      57608      19394      19619      20024      2500
# 2         0  ...     445007     542653     483003     473944     55000
# 3         0  ...        601        221       -159        567       380
# 4         0  ...      12108      12211      11793       3719      3329
# ...     ...  ...        ...        ...        ...        ...       ...
# 996      -1  ...      67782      -2618      95748     101299      3320
# 997       0  ...       8441      97041     103541       3632      5000
# 998      -1  ...       1114        657       1332        780         0
# 999      -2  ...          0          0          0          0         0
# 1000     -2  ...       3420       2527          0          0      9664
#
#       PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0        36681     10000      9000       689       679
# 1         1815       657      1000      1000       800
# 2        40000     38000     20239     13750     13770
# 3          601         0       581      1687      1542
# 4            0       432      1000      1000      1000
# ...        ...       ...       ...       ...       ...
# 996       5000         0    100000      7186         0
# 997       2000     89000      6500        91      1504
# 998       2806      2256      2274       780         0
# 999          0         0         0         0         0
# 1000      3420      2612         0         0         0
#
# [1001 rows x 23 columns]

# %%
y = data['default payment next month']
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 996     0
# 997     0
# 998     0
# 999     1
# 1000    1
# Name: default payment next month, Length: 1001, dtype: int64

# %%
#Splitting the data to training data & Test data
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state = 50)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (1001, 23) (750, 23) (251, 23)

# %%
#preprocessing steps
train_scaler=StandardScaler()
test_scaler=StandardScaler()

# %%
#Data Standardization
scaled_train_data = train_scaler.fit_transform(x_train)
scaled_test_data = train_scaler.transform(x_test)

# %% [raw]
# In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# %%
# Model Training using Decision Tree Classifier
model = DecisionTreeClassifier()

# %%
# training the model with training data
model.fit(x_train, y_train)
predictions = model.predict(scaled_train_data)
# Out:
# C:\Users\sapta\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
# accuracy score on training data
accuracy_score(y_train,predictions)
# Out:
# 0.796

# %%
# Hyper-parameter tuning to find the best parameters

# %%
model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
param_dist = {
    "criterion":["gini","entropy"],
    "max_depth":[1,2,3,4,5,6,None],
    "splitter":["best","random"],
    "min_samples_split":[1,2,3,4,5,6,None],
    "min_samples_leaf":[1,2,3,4,5,6,None]
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(model,param_grid=param_dist, cv=5,verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 1372 candidates, totalling 6860 fits
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.767 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.820 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.833 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=3, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=3, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=3, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=3, splitter=random;, score=0.787 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.787 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.767 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.787 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.820 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=3, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=3, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=3, splitter=random;, score=0.767 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=3, splitter=random;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.767 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=2, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.747 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.773 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=3, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=3, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=3, splitter=random;, score=0.767 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=3, splitter=random;, score=0.767 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.787 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=5, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=5, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=5, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=5, splitter=random;, score=0.787 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=5, splitter=random;, score=0.820 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=3, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.833 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=3, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=3, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=3, splitter=random;, score=0.767 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=3, splitter=random;, score=0.813 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, splitter=random;, score=0.787 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.813 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.820 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=6, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=6, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=6, splitter=random;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=6, splitter=random;, score=0.820 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=3, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=3, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=3, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=3, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=3, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.813 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.820 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.787 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.787 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.760 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.713 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.767 total time=   0.0s
# ...
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=0.767 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=0.820 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.733 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.667 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.733 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.713 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.747 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.680 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.767 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.787 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.807 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=6, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=3, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=3, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=3, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=3, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=3, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=3, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=3, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=3, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=3, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=3, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=5, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=5, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=5, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=5, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=5, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=5, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=5, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=5, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=5, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=5, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=None, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=None, min_samples_split=None, splitter=random;, score=nan total time=   0.0s
# C:\Users\sapta\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2660 fits failed out of a total of 6860.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 840 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sapta\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sapta\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\sapta\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 250, in fit
#     raise ValueError(
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
# --------------------------------------------------------------------------------
# 840 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sapta\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sapta\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\sapta\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 258, in fit
#     if not 0.0 < self.min_samples_split <= 1.0:
# TypeError: '<' not supported between instances of 'float' and 'NoneType'
#
# --------------------------------------------------------------------------------
# 980 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sapta\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sapta\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\sapta\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 241, in fit
#     if not 0.0 < self.min_samples_leaf <= 0.5:
# TypeError: '<' not supported between instances of 'float' and 'NoneType'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\sapta\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.76266667 ...        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3, 4, 5, 6, None],
#                          'min_samples_leaf': [1, 2, 3, 4, 5, 6, None],
#                          'min_samples_split': [1, 2, 3, 4, 5, 6, None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_leaf=6, min_samples_split=6,
#                        splitter='random')

# %%
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'min_samples_leaf': 6,
#  'min_samples_split': 6,
#  'splitter': 'random'}

# %%
model1 = DecisionTreeClassifier(criterion='gini', max_depth=2, min_samples_leaf=3,min_samples_split=4, splitter='random')
model1.fit(scaled_train_data,y_train)
y_pred = model1.predict(scaled_test_data)
accuracy_score(y_test, y_pred)*100
# Out:
# 82.07171314741036

# %%
# Predictive Modeling with random readings from the user based array

# %%
# Checking head values that may be used later for predictions
data.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0      9000       689       679                           0
# 1      1000      1000       800                           0
# 2     20239     13750     13770                           0
# 3       581      1687      1542                           0
# 4      1000      1000      1000                           0
#
# [5 rows x 24 columns]

# %%
input_data = np.array([[55000,1,2,1,59,-1,0,-1,0,0,0,8100,
                                        6000,35000,21000,20000,20000,2000,
                                        37000,11000,9000,700,700]])
# standardize the data
std_data = train_scaler.fit_transform(input_data)

prediction = model1.predict(std_data)
print(prediction)


if (prediction == 0):
  print("The person is not a credit card defaulter")

else:
  print("The person is a credit card defaulter")
# Out:
# [0]
# The person is not a credit card defaulter
